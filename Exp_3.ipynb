# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti-yadav-07/Deep-Learning/blob/main/Exp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub, os, pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

path = kagglehub.dataset_download("alyelbadry/house-pricing-dataset")
df = pd.read_csv(os.path.join(path, os.listdir(path)[0]))

df = df.drop(columns=[c for c in ['id','date'] if c in df.columns])

df = pd.get_dummies(df, drop_first=True)

X, y = df.drop('price', axis=1), df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = keras.Sequential([
    keras.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.fit(X_train, y_train, epochs=100, verbose=0)

pred = model.predict(X_test[:1])
print("Predicted:", pred[0][0])
print("Actual:", y_test.iloc[0])
# Out:
# Using Colab cache for faster access to the 'house-pricing-dataset' dataset.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Predicted: 227543.02
# Actual: 206000.0
