# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti-yadav-07/Deep-Learning/blob/main/Exp%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

model = keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(units=1)
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.1), loss='mean_squared_error')
model.fit(celsius, fahrenheit, epochs=1000, verbose=0)

test_value = np.array([[25.0]])
prediction = model.predict(test_value)

print("Model Train")
print(f"25°C = {prediction[0][0]:.2f}°F")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 25°C = 76.88°F

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Training data
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# Build model
model = keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(units=1)
])

# Compile model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_squared_error'
)

# Train model
model.fit(celsius, fahrenheit, epochs=1000, verbose=0)

# Test value
test_value = np.array([[25.0]])
prediction = model.predict(test_value)

# Output
print("Model Trained Successfully")

# Actual mathematical formula
print("\nActual Formula:")
print("F = (9/5) * C + 32")

# Model prediction
print("\nModel Prediction:")
print(f"25°C = {prediction[0][0]:.2f}°F")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model Trained Successfully
#
# Actual Formula:
# F = (9/5) * C + 32
#
# Model Prediction:
# 25°C = 76.86°F

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

model = keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(units=1)
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.1), loss='mean_squared_error')
model.fit(celsius, fahrenheit, epochs=1000, verbose=0)

test_value = np.array([[25.0]])
prediction = model.predict(test_value)

formula_result = (9/5) * 25 + 32

weight = model.layers[0].get_weights()[0][0][0]
bias = model.layers[0].get_weights()[1][0]

print("Model Trained")
print("Formula Result:", formula_result)
print("Model Prediction:", round(prediction[0][0], 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model Trained
# Formula Result: 77.0
# Model Prediction: 76.88
